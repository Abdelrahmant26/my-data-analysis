# %% [markdown]
# # Introduction to restaurants quality to attract tourists in Alexandria, Egypt

# %% [markdown]
# I will be using the foursquare API essentialy to get all the restaurants details.

# %% [markdown]
# restaurants are the most effective places to attract people.

# %% [markdown]
# All data will be mentioned are based ion foursquare database.
