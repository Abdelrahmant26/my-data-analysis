# %% [markdown]
# # What I will do:

# %% [markdown]
# I will segment restaurants according to:

# %% [markdown]
# 1-Rating

# %% [markdown]
# 2-Quality

# %% [markdown]
# 3-Pricings

# %% [markdown]
# 4-Distance to Alex beach

# %% [markdown]
# in order to find how much it will be good to go to a restaurant in Alexandria, Egypt.

# %% [markdown]
# # All the required data will be extracted from foursquar API database

# %% [markdown]
# As we nust guarantee that theose informations that we extracted is not wrong in order to make sure of the notebook truth.

# %% [markdown]
# # Methadology

# %% [markdown]
# i will first extract the 'json' data frame and normalize it.
#
# second : I will filter,clean,sort the Data I got.
#
# Third: I will study all the restaurants according to the ratings,distance from beach,overall quality
#
# fourth: I will analyse the filtered data and make a decision depending  on the data
#
# fifth: I will make a conclusion depending on the analysis and decide wether it is good or not to visit restaurants in Alexandria, Egypt.

# %% [markdown]
# # Results

# %% [markdown]
#  I will analyse the filtered data and make a decision depending on the data to make 'PREDICTFUL RESULTS'

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# The conclusion will mostly depend on the analysed data
#
# But we must take into considiration other factors of attracting or repulsion of tourists like:
#
# attraction:(monuments, attractive locations, proximity of water)
# repulsion:(noise, crowd, heavy traffic)
