# %% [markdown]
# # The goodeness of visiting a restaurant in Alex, Egypt

# %% [markdown]
# # Introduction

# %% [markdown]
# Visiting restaurants is one of the most attaracting venue for tourists or the new neighborhoods.
#
# This also contribute in makking some one feel 'comfortable' in a place or no.
#
# So, it is so important to study its benifit and wether it is good or not
#
# And I have chosen to study the region of Alexandria, Egypt as:
#
# 1-It is famous place and attarcting a lot of tourists and native citizens.
#
# 2-Egypt has a lot of another attarcting places and attracting monuments
#
# 3-The nature of egyptian citizens wholove to be kind to tourits
#
# 4-And finally the nature of the traditional food in Alexandria, Egypt which is vry delecious

# %% [markdown]
# # Problem

# %% [markdown]
# As I said ... a lot of tourists are willing to visit Egypt so it is important to study wether it is good or not

# %% [markdown]
# # Data acquisition and cleaning

# %% [markdown]
# # Data sources

# %% [markdown]
# I mainly used imported and depend on the data from:
# foursquare API database
#
# As we must guarantee that the information we use is correct.
#
# And especialy I will use their restaurants database in the region od Alexandria, Egypt.

# %% [markdown]
# # Data cleaning

# %% [markdown]
# I mainly cleaned un necessary data like pictures and some other unneccessary information.
#
# Then I deleted the unrated or unknown restaurants to make sure all information is crystal clear.

# %% [markdown]
# # Feature selection

# %% [markdown]
# I mainly searched for the high rating restaurants as well as:
#
# 1-ratings
#
# 2-quality
#
# 3-proximity from land or beach

# %% [markdown]
# # Observations

# %% [markdown]
# We will see from the main notebook the following:
#
# 1-The most of the restaurants are near the beach.
#
# 2-the overall quality is good.
#
# 3-the over all ratings is very good.
#
# as well as:
#
# 1-considering the other attractive locations.
#
# 2-The overall costs.

# %% [markdown]
# # Conclusion

# %% [markdown]
# As we can see we can concluse the following:
#
# The over all costs,qulaity,pricing,ratings,kind treating is so good.
#
# the best and final conclusion based on our research depending on the data sourse from foursquare:
#
# Is that it is very good to visit or to recomment for some one to visit restaurants in region Alexandria, Egypt.

# %% [markdown]
# # Future directions

# %% [markdown]
# As tourists frequently visit restaurants in Alexandia, Egypt
#
# All of the following:
#
# 1-Rating
#
# 2-pricing
#
# 3-quality
#
# 4-comfortability
#
# 5-number of restaurants
#
# 6-The huge number of restaurants categories
#
# Will gradually increase so that it will be better than what I explained in this report 'IN THE FUTURE' .

# %% [markdown]
# Hope this report is useful to you and informational to you.
