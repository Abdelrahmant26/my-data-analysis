# %% [markdown]
# # Introduction to comfortability rate in toronto according to venues available

# %% [raw]
# I will be using the foursquare API essentialy to get all the neighborhood details.

# %% [markdown]
# # and data source is https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M
