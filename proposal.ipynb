# %% [markdown]
# # I will use foursquare API to get:

# %% [raw]
# the near restaurant

# %% [raw]
# caffe

# %% [raw]
# markets

# %% [markdown]
# then I will decide what region is the best to live in.
